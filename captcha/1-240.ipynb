# %%
def generate_exam_topics():
    base_string = "oracle 1z0-808 question {} exam topics"
    topics = [base_string.format(i) for i in range(1, 241)]
    return topics

for topic in generate_exam_topics():
    print(topic)
# Out:
# oracle 1z0-808 question 1 exam topics
# oracle 1z0-808 question 2 exam topics
# oracle 1z0-808 question 3 exam topics
# oracle 1z0-808 question 4 exam topics
# oracle 1z0-808 question 5 exam topics
# oracle 1z0-808 question 6 exam topics
# oracle 1z0-808 question 7 exam topics
# oracle 1z0-808 question 8 exam topics
# oracle 1z0-808 question 9 exam topics
# oracle 1z0-808 question 10 exam topics
# oracle 1z0-808 question 11 exam topics
# oracle 1z0-808 question 12 exam topics
# oracle 1z0-808 question 13 exam topics
# oracle 1z0-808 question 14 exam topics
# oracle 1z0-808 question 15 exam topics
# oracle 1z0-808 question 16 exam topics
# oracle 1z0-808 question 17 exam topics
# oracle 1z0-808 question 18 exam topics
# oracle 1z0-808 question 19 exam topics
# oracle 1z0-808 question 20 exam topics
# oracle 1z0-808 question 21 exam topics
# oracle 1z0-808 question 22 exam topics
# oracle 1z0-808 question 23 exam topics
# oracle 1z0-808 question 24 exam topics
# ...
