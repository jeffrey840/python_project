# %%
from bs4 import BeautifulSoup

# Your provided HTML content starting from the <body> tag
html_content = """
<body class="home2">
<!-- Google Tag Manager (noscript) -->
<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NPZ5XJCD"
height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
<!-- End Google Tag Manager (noscript) -->

<!--Full width header Start-->
<div class="full-width-header">
<!-- Toolbar Start -->
<div class="rs-toolbar">
	<div class="container">
		<div class="row d-print-none">
			<div class="col-md-6">
				<div class="rs-toolbar-left">
					<div class="welcome-message">
						<i class="fa fa-bank"></i><span>Welcome to ExamTopics</span>
					</div>
				</div>
			</div>
			<div class="col-md-6">
				<div class="rs-toolbar-right">
					<div class="account-menu">
						<ul>

								<li><a href="/login/" data-toggle="modal" data-target="#login-modal" class="mr-2">Login</a> |</li>
								<li><a href="/signup/">Sign up</a></li>

							<li class="spacer"></li>
						</ul>
					</div>
					<div class="toolbar-share-icon">
						<ul>

							<li><a href="https://www.facebook.com/ExamTopicsOnline/"><i class="fa fa-facebook"></i></a></li>

							<li><a href="https://twitter.com/TopicsExam"><i class="fa fa-twitter"></i></a></li>

							<li><a href="https://www.youtube.com/channel/UC4CThW97vf8rHFYcvK2disg"><i class="fa fa-youtube"></i></a></li>

							<li><a href="https://www.reddit.com/r/ExamTopics/"><i class="fa fa-reddit"></i></a></li>

							<li><a href="https://www.pinterest.com/examtopics/"><i class="fa fa-pinterest"></i></a></li>

						</ul>
					</div>
					<!--<a href="#" class="apply-btn">Apply Now</a>-->
				</div>
			</div>
		</div>
	</div>
</div>
<!-- Toolbar End -->

<!--Header Start-->
<header id="rs-header" class="rs-header">
<!-- Header Top Start -->
<div class="rs-header-top">
	<div class="container">
		<div class="row">
			<div class="col-lg-5 col-md-12 rs-vertical-middle">
				<div class="logo-area">
					<img src="/assets/images/et/ExamTopics-Logo-Smaller.png" alt="ExamTopics Logo">
					<br class="hidden-desktop">
					<span class="moto hypen-separator hidden-mobile">-</span>
					<span class="moto">Expert Verified, Online, <strong>Free</strong>.</span>
				</div>
			</div>
			<div class="col-lg-7 col-md-12 d-print-none">
				<div class="row">
					<div class="col-sm-4">
						<!-- Placeholder -->
					</div>
					<div class="col-sm-4">
						<div class="header-contact">
							<div id="info-details" class="widget-text">
								<i class="glyph-icon flaticon-email"></i>
								<div class="info-text">
									<a href="mailto:team@examtopics.com">
										<span>Mail Us</span>
										team@examtopics.com
									</a>
								</div>
							</div>
						</div>
					</div>
					<div class="col-sm-4">
						<div class="header-contact">
							<div id="address-details" class="widget-text">





							</div>
						</div>
					</div>
				</div>
			</div>
		</div>
	</div>
</div>
<!-- Header Top End -->

	<!-- Menu Start -->
	<div class="menu-area menu-sticky d-print-none">
		<div class="container">
			<div class="main-menu">
				<div class="row">
					<div class="col-sm-12">
						<!-- <div id="logo-sticky" class="text-center">
							<a href="index.html"><img src="/assets/images/logo.png" alt="logo"></a>
						</div> -->
						<a class="rs-menu-toggle rs-menu-toggle-close"><i class="fa fa-bars"></i>Menu</a>
						<nav class="rs-menu rs-menu-close" style="height: 0px;">
							<ul class="nav-menu">
								<!-- Home -->
								<li class="current-menu-item current_page_item"><a href="/" class="home">Home</a></li>
								<!-- End Home -->
								<li><a href="https://unlimited.examtopics.com/">UNLIMITED ACCESS</a></li>
								<!-- Drop Down Pages Start -->
								<li class="rs-mega-menu mega-rs"><a href="#">Popular Exams</a>
									<ul class="mega-menu">
										<li class="mega-menu-container">
											<div class="mega-menu-innner">
















												<div class="single-magemenu">
													<ul class="sub-menu">



														<li><a href="/exams/amazon/">Amazon</a></li>




														<li><a href="/exams/isaca/">Isaca</a></li>




														<li><a href="/exams/vmware/">VMware</a></li>




														<li><a href="/exams/isc/">ISC</a></li>




														<li><a href="/exams/palo-alto-networks/">Palo Alto Networks</a></li>


													</ul>
												</div>



												<div class="single-magemenu">
													<ul class="sub-menu">



														<li><a href="/exams/cisco/">Cisco</a></li>




														<li><a href="/exams/google/">Google</a></li>




														<li><a href="/exams/juniper/">Juniper</a></li>




														<li><a href="/exams/the-open-group/">The Open Group</a></li>




														<li><a href="/exams/eccouncil/">ECCouncil</a></li>


													</ul>
												</div>



												<div class="single-magemenu">
													<ul class="sub-menu">



														<li><a href="/exams/microsoft/">Microsoft</a></li>




														<li><a href="/exams/salesforce/">Salesforce</a></li>




														<li><a href="/exams/servicenow/">ServiceNow</a></li>




														<li><a href="/exams/fortinet/">Fortinet</a></li>




														<li><a href="/exams/oracle/">Oracle</a></li>


													</ul>
												</div>
















											</div>
										</li>
									<div class="sub-menu-close"><i class="fa fa-times" aria-hidden="true"></i>Close</div></ul>
								<span class="rs-menu-parent"><i class="fa fa-angle-down" aria-hidden="true"></i></span></li>
								<!--Drop Down Pages End -->

								<li><a href="/exams/">View All Exams</a></li>
								<li><a href="https://certification.examtopics.com/freedownload" target="_blank">Download Free</a></li>
								<!-- <li><a href="/news/">News</a></li>
								<li><a href="/#about-us">About</a></li> -->
								<li><a href="/#contact-us">Contact</a></li>
								<li><a href="/discussions/">Forum</a></li>


									<li class="d-md-none"><a href="/login/" data-toggle="modal" data-target="#login-modal">Login</a></li>
									<li class="d-md-none"><a href="/signup/">Sign up</a></li>

							</ul>
						</nav>
						<a class="hidden-xs rs-search" data-target=".search-modal" data-toggle="modal" href="#"><i class="fa fa-search"></i></a>
					</div>
				</div>
			</div>
		</div>
	</div>
	<!-- Menu End -->
</header>
<!--Header End-->

</div>
<!--Full width header End-->









    <div class="sec-spacer" style="padding: 60px 0px; ">
        <div class="container">
            <div class="exam-view-header">

                <div class="row">
                    <div class="col-12 col-sm-8 offset-sm-2 d-print-none">



                    </div>
                </div>

<!-- exam-view45 -->

<!-- rrr [/exams/oracle/1z0-808/view/3/] -->


<script type="text/javascript">
dataLayer.push({ ecommerce: null });  // Clear the previous ecommerce object.
dataLayer.push({
  event: "view_item",
  ecommerce: {
    currency: "USD",
    items: [
    {

      item_id: "Oracle",
      item_name: "Oracle",
      affiliation: "Examtopics",
      item_brand: "Examtopics",
      item_category: "View All Exams",
      item_exam_name: "1z0-808",
    }
    ]
  }
});
</script>
                <div class="row d-print-none">
                    <div class="col-lg-6 offset-lg-3">

                        <div class="card">
                            <div class="card-header alert alert-info text-center">
                                <h1 id="exam-box-title">
                                    Oracle 1z0-808 Exam Actual Questions

                                    <span class="page-indicator">(P. 3)</span>

                                </h1>
                            </div>
                            <div class="card-body">
                                <h5 class="card-title">The questions for 1z0-808 were last updated on
                                    Oct. 17, 2023.</h5>
                                <div class="card-text">
                                    <ul>
                                        <li>Viewing page <strong>3</strong> out of
                                            47 pages.
                                        </li>
                                        <li>Viewing questions 11-15 out of
                                            240 questions
                                        </li>
                                    </ul>
                                </div>
                            </div>
                        </div>

                    </div>
                </div>
            </div>
<!-- exam-view46 -->

            <div class="row">
                <div class="col-12 text-right mb-3">
                   <!-- 3 --> <a href="/exams/oracle/1z0-808/custom-view/" class="btn btn-primary">
                        <i class="fa fa-gear"></i> Custom View Settings
                    </a>
                </div>
            </div>


<!-- exam-view47 -->
            <div class="row">
                <div class="col-12">
                    <div class="questions-container">




<!-- exam-view48 -->
                            <!-- Question -->
                            <div class="card exam-question-card">
                                <div class="card-header text-white bg-primary">
                                    Question #11
                                    <span class="question-title-topic pull-right">
                                        Topic 1
                                    </span>
                                </div>
                                <div class="card-body question-body" data-id="836650">
                                    <p class="card-text">


                                            Given:<br><img src="/assets/media/exam-media/04353/0001200001.png" class="in-exam-image"><br>And given the code fragment:<br>Book book1 = new EBook();<br>book1.readBook();<br>Which option enables the code to compile?<br><img src="/assets/media/exam-media/04353/0001200002.png" class="in-exam-image"><br>

                                    </p>
<!-- exam-view49 -->

                                        <div class="question-choices-container">
                                            <div class="voted-answers-tally d-none">

                                                        <script id="836650" type="application/json">[{"voted_answers": "D", "vote_count": 5, "is_most_voted": true}]</script>

                                            </div>
                                            <ul>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="A">
                                                                A.
                                                            </span>

                                                        Option A
                                                    </li>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="B">
                                                                B.
                                                            </span>

                                                        Option B
                                                    </li>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="C">
                                                                C.
                                                            </span>

                                                        Option C
                                                    </li>

                                                    <li class="multi-choice-item correct-hidden">

                                                            <span class="multi-choice-letter" data-choice-letter="D">
                                                                D.
                                                            </span>

                                                        Option D
                                                    <span class="badge badge-success most-voted-answer-badge" title="" style="display: none;" data-original-title="This answer is currently the most voted for in the discussion">
                Most Voted
            </span></li>

                                            </ul>
                                        </div>

<!-- exam-view410 -->
                                    <a href="#" class="btn btn-primary reveal-solution d-print-none">Reveal Solution</a>
                                    <a href="#" class="btn btn-primary hide-solution d-none d-print-none">Hide Solution</a>

                                        <a href="#" class="btn btn-secondary question-discussion-button d-print-none">
                                            <i class="fa fa-comment"></i>
                                            &nbsp; Discussion &nbsp;

                                                <span class="badge badge-pill badge-light">7</span>


                                        </a>

<!-- exam-view411 -->
                                    <p class="card-text question-answer bg-light white-text">
                                        <span class="correct-answer-box"><strong>Correct Answer:</strong>
                                            <span class="correct-answer">D</span>

                                                <a href="#" class="vote-answer-button ml-1 d-print-none" data-toggle="tooltip" title="" data-original-title="Vote an answer">🗳️</a>
                                                                                        <br>
                                        </span>

                                        <span class="answer-description">

                                        </span>
                                    <div class="voting-summary col-12 col-sm-6 col-lg-4 pt-2 pb-2" style="font-size: 0.9em"><i>Community vote distribution</i><!-- Additional optional vote button: <a href="javascript:void(0)" data-toggle="tooltip" class="vote-answer-button" title="Vote an answer">🗳️</a>--><div class="progress vote-distribution-bar"><div class="vote-bar progress-bar bg-primary" data-toggle="tooltip" role="progressbar" style="width: 100%; display: flex;" aria-valuenow="15" aria-valuemin="0" aria-valuemax="100" data-original-title="5 votes." title="">D (100%)</div><div class="vote-bar progress-bar bg-info" data-toggle="tooltip" role="progressbar" style="width: 25%; display: none;" aria-valuenow="30" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">C (25%)
                </div><div class="vote-bar progress-bar bg-success" data-toggle="tooltip" role="progressbar" style="width: 25%; display: none;" aria-valuenow="30" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">B (20%)
                </div><div class="vote-bar progress-bar bg-warning" data-toggle="tooltip" role="progressbar" style="width: 15%; display: none;" aria-valuenow="20" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">Other
                </div></div></div></p>
<!-- exam-view412 -->


                                </div>
                            </div>
                            <!-- / Question  -->




<!-- exam-view48 -->
                            <!-- Question -->
                            <div class="card exam-question-card">
                                <div class="card-header text-white bg-primary">
                                    Question #12
                                    <span class="question-title-topic pull-right">
                                        Topic 1
                                    </span>
                                </div>
                                <div class="card-body question-body" data-id="836651">
                                    <p class="card-text">


                                            Given:<br><img src="/assets/media/exam-media/04353/0001300001.png" class="in-exam-image"><br>What is the result?<br>

                                    </p>
<!-- exam-view49 -->

                                        <div class="question-choices-container">
                                            <div class="voted-answers-tally d-none">

                                                        <script id="836651" type="application/json">[{"voted_answers": "C", "vote_count": 13, "is_most_voted": true}]</script>

                                            </div>
                                            <ul>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="A">
                                                                A.
                                                            </span>

                                                        A B C D
                                                    </li>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="B">
                                                                B.
                                                            </span>

                                                        A C D
                                                    </li>

                                                    <li class="multi-choice-item correct-hidden">

                                                            <span class="multi-choice-letter" data-choice-letter="C">
                                                                C.
                                                            </span>

                                                        A C D D
                                                    <span class="badge badge-success most-voted-answer-badge" title="" style="display: none;" data-original-title="This answer is currently the most voted for in the discussion">
                Most Voted
            </span></li>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="D">
                                                                D.
                                                            </span>

                                                        A B D
                                                    </li>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="E">
                                                                E.
                                                            </span>

                                                        A B D C
                                                    </li>

                                            </ul>
                                        </div>

<!-- exam-view410 -->
                                    <a href="#" class="btn btn-primary reveal-solution d-print-none">Reveal Solution</a>
                                    <a href="#" class="btn btn-primary hide-solution d-none d-print-none">Hide Solution</a>

                                        <a href="#" class="btn btn-secondary question-discussion-button d-print-none">
                                            <i class="fa fa-comment"></i>
                                            &nbsp; Discussion &nbsp;

                                                <span class="badge badge-pill badge-light">51</span>


                                        </a>

<!-- exam-view411 -->
                                    <p class="card-text question-answer bg-light white-text">
                                        <span class="correct-answer-box"><strong>Correct Answer:</strong>
                                            <span class="correct-answer">C</span>

                                                <a href="#" class="vote-answer-button ml-1 d-print-none" data-toggle="tooltip" title="" data-original-title="Vote an answer">🗳️</a>
                                                                                        <br>
                                        </span>

                                        <span class="answer-description">

                                        </span>
                                    <div class="voting-summary col-12 col-sm-6 col-lg-4 pt-2 pb-2" style="font-size: 0.9em"><i>Community vote distribution</i><!-- Additional optional vote button: <a href="javascript:void(0)" data-toggle="tooltip" class="vote-answer-button" title="Vote an answer">🗳️</a>--><div class="progress vote-distribution-bar"><div class="vote-bar progress-bar bg-primary" data-toggle="tooltip" role="progressbar" style="width: 100%; display: flex;" aria-valuenow="15" aria-valuemin="0" aria-valuemax="100" data-original-title="13 votes." title="">C (100%)</div><div class="vote-bar progress-bar bg-info" data-toggle="tooltip" role="progressbar" style="width: 25%; display: none;" aria-valuenow="30" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">C (25%)
                </div><div class="vote-bar progress-bar bg-success" data-toggle="tooltip" role="progressbar" style="width: 25%; display: none;" aria-valuenow="30" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">B (20%)
                </div><div class="vote-bar progress-bar bg-warning" data-toggle="tooltip" role="progressbar" style="width: 15%; display: none;" aria-valuenow="20" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">Other
                </div></div></div></p>
<!-- exam-view412 -->


                                </div>
                            </div>
                            <!-- / Question  -->




<!-- exam-view48 -->
                            <!-- Question -->
                            <div class="card exam-question-card">
                                <div class="card-header text-white bg-primary">
                                    Question #13
                                    <span class="question-title-topic pull-right">
                                        Topic 1
                                    </span>
                                </div>
                                <div class="card-body question-body" data-id="836652">
                                    <p class="card-text">


                                            Given:<br><img src="/assets/media/exam-media/04353/0001400001.png" class="in-exam-image"><br>Which code fragment should you use at line n1 to instantiate the dvd object successfully?<br><img src="/assets/media/exam-media/04353/0001400002.png" class="in-exam-image"><br>

                                    </p>
<!-- exam-view49 -->

                                        <div class="question-choices-container">
                                            <div class="voted-answers-tally d-none">

                                                        <script id="836652" type="application/json">[{"voted_answers": "C", "vote_count": 5, "is_most_voted": true}]</script>

                                            </div>
                                            <ul>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="A">
                                                                A.
                                                            </span>

                                                        Option A
                                                    </li>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="B">
                                                                B.
                                                            </span>

                                                        Option B
                                                    </li>

                                                    <li class="multi-choice-item correct-hidden">

                                                            <span class="multi-choice-letter" data-choice-letter="C">
                                                                C.
                                                            </span>

                                                        Option C
                                                    <span class="badge badge-success most-voted-answer-badge" title="" style="display: none;" data-original-title="This answer is currently the most voted for in the discussion">
                Most Voted
            </span></li>

                                                    <li class="multi-choice-item">

                                                            <span class="multi-choice-letter" data-choice-letter="D">
                                                                D.
                                                            </span>

                                                        Option D
                                                    </li>

                                            </ul>
                                        </div>

<!-- exam-view410 -->
                                    <a href="#" class="btn btn-primary reveal-solution d-print-none">Reveal Solution</a>
                                    <a href="#" class="btn btn-primary hide-solution d-none d-print-none">Hide Solution</a>

                                        <a href="#" class="btn btn-secondary question-discussion-button d-print-none">
                                            <i class="fa fa-comment"></i>
                                            &nbsp; Discussion &nbsp;

                                                <span class="badge badge-pill badge-light">14</span>


                                        </a>

<!-- exam-view411 -->
                                    <p class="card-text question-answer bg-light white-text">
                                        <span class="correct-answer-box"><strong>Correct Answer:</strong>
                                            <span class="correct-answer">C</span>

                                                <a href="#" class="vote-answer-button ml-1 d-print-none" data-toggle="tooltip" title="" data-original-title="Vote an answer">🗳️</a>
                                                                                        <br>
                                        </span>

                                        <span class="answer-description">

                                        </span>
                                    <div class="voting-summary col-12 col-sm-6 col-lg-4 pt-2 pb-2" style="font-size: 0.9em"><i>Community vote distribution</i><!-- Additional optional vote button: <a href="javascript:void(0)" data-toggle="tooltip" class="vote-answer-button" title="Vote an answer">🗳️</a>--><div class="progress vote-distribution-bar"><div class="vote-bar progress-bar bg-primary" data-toggle="tooltip" role="progressbar" style="width: 100%; display: flex;" aria-valuenow="15" aria-valuemin="0" aria-valuemax="100" data-original-title="5 votes." title="">C (100%)</div><div class="vote-bar progress-bar bg-info" data-toggle="tooltip" role="progressbar" style="width: 25%; display: none;" aria-valuenow="30" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">C (25%)
                </div><div class="vote-bar progress-bar bg-success" data-toggle="tooltip" role="progressbar" style="width: 25%; display: none;" aria-valuenow="30" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">B (20%)
                </div><div class="vote-bar progress-bar bg-warning" data-toggle="tooltip" role="progressbar" style="width: 15%; display: none;" aria-valuenow="20" aria-valuemin="0" aria-valuemax="100" data-original-title="" title="">Other
                </div></div></div></p>
<!-- exam-view412 -->


                                </div>
                            </div>
                            <!-- / Question  -->




<!-- exam-view48 -->
                            <!-- Question -->
                            <div class="card exam-question-card">
                                <div class="card-header text-white bg-primary">
                                    Question #14
                                    <span class="question-title-topic pull-right">
                                        Topic 1
                                    </span>
                                </div>
                                <div class="card-body question-body" data-id="836653">
                                    <p class="card-text">


                                            Given the code fragment:<br><img src="/assets/media/exam-media/04353/0001500001.png" class="in-exam-image"><br>Which option can replace xxx to enable the code to print 135?<br>A.<br><img src="/assets/media/exam-media/04353/0001500002.png" class="in-exam-image"><br>B.<br><img src="/assets/media/exam-media/04353/0001500003.png" class="in-exam-image"><br>C.<br><img src="/assets/media/exam-media/04353/0001500004.png" class="in-exam-image"><br>D.<br><img src="/assets/media/exam-media/04353/0001500005.png" class="in-exam-image"><br>

                                    </p>
<!-- exam-view49 -->

"""

# Parse the HTML content using Beautiful Soup
soup = BeautifulSoup(html_content, 'html.parser')

# Find the questions container
questions_container = soup.select_one('div.sec-spacer > div > div:nth-child(3) > div > div.questions-container')

if questions_container:
    # Extract all questions
    questions = questions_container.find_all('div', class_='card exam-question-card', recursive=True)

    for idx, question_div in enumerate(questions, 1):
        print(f"Question {idx}:")

        # Extract the question text
        question_body = question_div.find('div', class_='card-body question-body')
        if question_body:
            question_text = question_body.p.get_text(strip=True)
            print(f"Text: {question_text}")
        else:
            print("Question text not found!")

        # Extract the image URL
        img_tag = question_div.find('img', class_='in-exam-image')
        if img_tag:
            image_url = img_tag['src']
            print(f"Image URL: {image_url}")
        else:
            print("Image not found!")

        # Extract the multiple-choice options
        options_container = question_div.find('div', class_='question-choices-container')
        if options_container:
            options = options_container.find_all('li', class_='multi-choice-item')
            for option in options:
                option_text = option.get_text(strip=True)
                print(f"Option: {option_text}")
        else:
            print("Options not found!")

        print("-" * 50)  # Separator for clarity
else:
    print("Questions container not found!")
# Out:
# Question 1:
# Text: Given:And given the code fragment:Book book1 = new EBook();book1.readBook();Which option enables the code to compile?
# Image URL: /assets/media/exam-media/04353/0001200001.png
# Option: A.Option A
# Option: B.Option B
# Option: C.Option C
# Option: D.Option DMost Voted
# --------------------------------------------------
# Question 2:
# Text: Given:What is the result?
# Image URL: /assets/media/exam-media/04353/0001300001.png
# Option: A.A B C D
# Option: B.A C D
# Option: C.A C D DMost Voted
# Option: D.A B D
# Option: E.A B D C
# --------------------------------------------------
# Question 3:
# Text: Given:Which code fragment should you use at line n1 to instantiate the dvd object successfully?
# Image URL: /assets/media/exam-media/04353/0001400001.png
# Option: A.Option A
# Option: B.Option B
# Option: C.Option CMost Voted
# Option: D.Option D
# --------------------------------------------------
# Question 4:
# Text: Given the code fragment:Which option can replace xxx to enable the code to print 135?A.B.C.D.
# Image URL: /assets/media/exam-media/04353/0001500001.png
# Options not found!
# --------------------------------------------------
